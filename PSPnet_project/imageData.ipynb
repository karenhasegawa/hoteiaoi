# %% [markdown]
# 画像をLabelmeで生成できるjsonファイルの"imageData"のデータ型に変更する方法

# %%
import base64

img_path = '/content/drive/MyDrive/PSPNet/data_dataset_voc_20220421_(1)/JPEGImages/DJI_0005.jpg'
encoded = base64.b64encode(open(img_path, "rb").read())
print(encoded)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
